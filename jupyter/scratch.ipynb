# %%
import parameterized_mortgage

# %%
mort = parameterized_mortgage.Loan(periodic_rate=3.1/12)

# %%
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='a9bf1c2a-2beb-4456-9faf-4e22597832c2'>
#   <div id="f603e022-20c8-49d6-bd9f-93317016501d" data-root-id="a9bf1c2a-2beb-4456-9faf-4e22597832c2" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
pn.Row(
    mort.param,
    mort.view_periodic_payment
)
# Out:
# Row
#     [0] Column(margin=(5, 10), name='Loan')
#         [0] StaticText(value='<b>Loan</b>')
#         [1] FloatInput(description='The principal o..., name='Principal', start=0, value=100000)
#         [2] FloatSlider(end=100, name='Periodic rate', value=0.25833333333333336)
#         [3] FloatInput(description='Number of periods o..., name='Number of periods', start=1, value=240)
#         [4] FloatInput(description='Calculated repayment d..., disabled=True, name='Periodic repayment', value=559.6168974207601)
#     [1] ParamMethod(method, _pane=Str, defer_load=False)

# %%
settings = pn.Param(
    mort, 
    parameters=[
        'principal',
        'periodic_rate',
        'number_of_periods'
    ]
)
settings
# Out:
# Param(Loan, parameters=['principal', ...])

# %%
w = pn.widgets.TextInput(value=pn.bind(lambda c: str(c), settings))
w
# Out:
# WARNING:param.TextInput00702: Setting non-parameter attribute watch=True using a mechanism intended only for parameters
# TextInput(value='284000.0')

# %%
pn.Column(settings, w)
# Out:
# Column
#     [0] Param(Loan, parameters=['principal', ...])
#     [1] TextInput(value='559.6168974207601')
